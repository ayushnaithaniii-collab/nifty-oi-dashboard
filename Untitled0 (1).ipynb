# %%
# !pip install nsepython
# Out:
# Collecting nsepython
#   Downloading nsepython-2.97-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from nsepython) (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from nsepython) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from nsepython) (1.16.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->nsepython) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->nsepython) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->nsepython) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->nsepython) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->nsepython) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->nsepython) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->nsepython) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->nsepython) (2026.5.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->nsepython) (1.17.0)
# Downloading nsepython-2.97-py3-none-any.whl (25 kB)
# Installing collected packages: nsepython
# Successfully installed nsepython-2.97

# %%
import requests
import pandas as pd

url = "https://service.upstox.com/option-analytics-tool/open/v1/strategy-chains?assetKey=NSE_INDEX%7CNifty+50&strikeCount=10&expiry=near_month"

headers = {"Accept": "application/json"}

response = requests.get(url, headers=headers)
print("Status:", response.status_code)
data = response.json()
print(data.keys())
# Out:
# Status: 400
# dict_keys(['timestamp', 'status', 'error', 'message', 'path'])

# %%
print(data['message'])
print(data['error'])
# Out:
# Bad Request

# %%
import yfinance as yf
import pandas as pd

nifty = yf.Ticker("^NSEI")
hist = nifty.history(period="5d")
print(hist)
# Out:
#                                    Open          High           Low  \
# Date
# 2026-05-29 00:00:00+05:30  23902.150391  24002.800781  23484.750000
# 2026-06-01 00:00:00+05:30  23654.500000  23733.699219  23357.949219
# 2026-06-02 00:00:00+05:30  23229.150391  23556.949219  23229.150391
# 2026-06-03 00:00:00+05:30  23415.949219  23459.650391  23151.500000
# 2026-06-04 00:00:00+05:30  23282.449219  23462.300781  23247.300781
#
#                                   Close   Volume  Dividends  Stock Splits
# Date
# 2026-05-29 00:00:00+05:30  23547.750000  1198000        0.0           0.0
# 2026-06-01 00:00:00+05:30  23382.599609   421700        0.0           0.0
# 2026-06-02 00:00:00+05:30  23483.550781   511900        0.0           0.0
# 2026-06-03 00:00:00+05:30  23405.599609   450100        0.0           0.0
# 2026-06-04 00:00:00+05:30  23422.349609        0        0.0           0.0

# %%
import yfinance as yf

nifty = yf.Ticker("^NSEI")
print(nifty.options)
# Out:
# ()

# %%
print(data['status'])
print(len(data['data']))
print(data)

# %%
url2 = "https://api.upstox.com/v2/option/contract"

params2 = {
    "instrument_key": "NSE_INDEX|Nifty 50"
}

response2 = requests.get(url2, headers=headers, params=params2)
data2 = response2.json()

# Print all available expiry dates
for item in data2['data'][:10]:
    print(item['expiry'])

# %%
# Get all unique expiry dates
expiries = list(set([item['expiry'] for item in data2['data']]))
expiries.sort()
for e in expiries:
    print(e)

# %%
params3 = {
    "instrument_key": "NSE_INDEX|Nifty 50",
    "expiry_date": "2026-06-09"
}

response3 = requests.get(
    "https://api.upstox.com/v2/option/chain",
    headers=headers,
    params=params3
)

data3 = response3.json()
print("Total strikes:", len(data3['data']))
print(data3['data'][0])

# %%
import pandas as pd

rows = []

for item in data3['data']:
    rows.append({
        'strike': item['strike_price'],
        'call_oi': item['call_options']['market_data']['oi'],
        'put_oi': item['put_options']['market_data']['oi'],
        'call_ltp': item['call_options']['market_data']['ltp'],
        'put_ltp': item['put_options']['market_data']['ltp'],
    })

df = pd.DataFrame(rows)
print(df.head(10))

# %%
import requests
import pandas as pd

# Your token
token = ""

headers = {
    "Authorization": f"Bearer {token}",
    "Accept": "application/json"
}

# Fetch options chain
params = {
    "instrument_key": "NSE_INDEX|Nifty 50",
    "expiry_date": "2026-06-09"
}

response = requests.get(
    "https://api.upstox.com/v2/option/chain",
    headers=headers,
    params=params
)

data3 = response.json()

# Build table
rows = []
for item in data3['data']:
    rows.append({
        'strike': item['strike_price'],
        'call_oi': item['call_options']['market_data']['oi'],
        'put_oi': item['put_options']['market_data']['oi'],
        'call_ltp': item['call_options']['market_data']['ltp'],
        'put_ltp': item['put_options']['market_data']['ltp'],
    })

df = pd.DataFrame(rows)
print(df.head(10))

# %%
import requests
import pandas as pd

token = "YOUR_TOKEN_HERE"

headers = {
    "Authorization": f"Bearer {token}",
    "Accept": "application/json"
}

url = "https://api.upstox.com/v2/option/chain"

params = {
    "instrument_key": "NSE_INDEX|Nifty 50",
    "expiry_date": "2026-06-05"
}

response = requests.get(url, headers=headers, params=params)
print("Status:", response.status_code)
data = response.json()
print(data.keys())

# %%
print(data3)

# %%
token = "YOUR_TOKEN_HERE"

# %%
print(token)

# %%
import requests

response = requests.get(
    "https://api.upstox.com/v2/option/chain",
    headers={
        "Authorization": f"Bearer {token}",
        "Accept": "application/json"
    },
    params={
        "instrument_key": "NSE_INDEX|Nifty 50",
        "expiry_date": "2026-06-16"
    }
)

data3 = response.json()
print(data3['status'])
print(len(data3['data']))

# %%
import pandas as pd

rows = []
for item in data3['data']:
    rows.append({
        'strike': item['strike_price'],
        'call_oi': item['call_options']['market_data']['oi'],
        'put_oi': item['put_options']['market_data']['oi'],
        'call_ltp': item['call_options']['market_data']['ltp'],
        'put_ltp': item['put_options']['market_data']['ltp'],
    })

df = pd.DataFrame(rows)
print(df.head(10))

# %%
total_call_oi = df['call_oi'].sum()
total_put_oi = df['put_oi'].sum()
pcr = total_put_oi / total_call_oi

print("Total Call OI:", total_call_oi)
print("Total Put OI:", total_put_oi)
print("PCR:", round(pcr, 2))

if pcr > 1.2:
    print("Signal: BULLISH - Put writers active")
elif pcr < 0.8:
    print("Signal: BEARISH - Call writers active")
else:
    print("Signal: NEUTRAL")

# %%
max_pain_strike = None
min_pain = float('inf')

for index, row in df.iterrows():
    strike = row['strike']

    # Total loss to option writers at this strike
    call_pain = ((df[df['strike'] < strike]['strike'] - strike).abs() * df[df['strike'] < strike]['call_oi']).sum()
    put_pain = ((df[df['strike'] > strike]['strike'] - strike).abs() * df[df['strike'] > strike]['put_oi']).sum()

    total_pain = call_pain + put_pain

    if total_pain < min_pain:
        min_pain = total_pain
        max_pain_strike = strike

print("Max Pain Strike:", max_pain_strike)

# %%
import yfinance as yf

nifty = yf.Ticker("^NSEI")
hist = nifty.history(period="1d")
spot = round(hist['Close'].iloc[-1])

distance = abs(spot - max_pain_strike)

print("Nifty Spot:", spot)
print("Max Pain:", max_pain_strike)
print("Distance:", distance, "points")
print("Max pain is", round((distance/spot)*100, 2), "% away from spot")

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

token = "YOUR_TOKEN_HERE"

headers = {
    "Authorization": f"Bearer {token}",
    "Accept": "application/json"
}

# Fetch options chain
response = requests.get(
    "https://api.upstox.com/v2/option/chain",
    headers=headers,
    params={
        "instrument_key": "NSE_INDEX|Nifty 50",
        "expiry_date": "2026-06-16"
    }
)

data3 = response.json()

# Build dataframe
rows = []
for item in data3['data']:
    rows.append({
        'strike': item['strike_price'],
        'call_oi': item['call_options']['market_data']['oi'],
        'put_oi': item['put_options']['market_data']['oi'],
        'call_ltp': item['call_options']['market_data']['ltp'],
        'put_ltp': item['put_options']['market_data']['ltp'],
    })

df = pd.DataFrame(rows)

# PCR
total_call_oi = df['call_oi'].sum()
total_put_oi = df['put_oi'].sum()
pcr = round(total_put_oi / total_call_oi, 2)

# Max Pain
max_pain_strike = None
min_pain = float('inf')
for index, row in df.iterrows():
    strike = row['strike']
    call_pain = ((df[df['strike'] < strike]['strike'] - strike).abs() * df[df['strike'] < strike]['call_oi']).sum()
    put_pain = ((df[df['strike'] > strike]['strike'] - strike).abs() * df[df['strike'] > strike]['put_oi']).sum()
    total_pain = call_pain + put_pain
    if total_pain < min_pain:
        min_pain = total_pain
        max_pain_strike = strike

# Spot price
nifty = yf.Ticker("^NSEI")
spot = round(nifty.history(period="1d")['Close'].iloc[-1])

# Plot
plt.figure(figsize=(14, 6))
plt.bar(df['strike'], df['call_oi'], color='red', alpha=0.7, label='Call OI')
plt.bar(df['strike'], df['put_oi'], color='green', alpha=0.7, label='Put OI')
plt.axvline(x=spot, color='yellow', linestyle='--', label=f'Spot: {spot}')
plt.axvline(x=max_pain_strike, color='white', linestyle='--', label=f'Max Pain: {max_pain_strike}')
plt.title(f'Nifty OI | PCR: {pcr} | Max Pain: {max_pain_strike}')
plt.xlabel('Strike Price')
plt.ylabel('Open Interest')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print(f"Spot: {spot} | Max Pain: {max_pain_strike} | PCR: {pcr}")

# %%
import time
from datetime import datetime

pcr_history = []

print("Recording PCR every 30 seconds... (will run 5 times)")

for i in range(5):
    response = requests.get(
        "https://api.upstox.com/v2/option/chain",
        headers=headers,
        params={
            "instrument_key": "NSE_INDEX|Nifty 50",
            "expiry_date": "2026-06-16"
        }
    )

    data = response.json()

    rows = []
    for item in data['data']:
        rows.append({
            'strike': item['strike_price'],
            'call_oi': item['call_options']['market_data']['oi'],
            'put_oi': item['put_options']['market_data']['oi'],
        })

    temp_df = pd.DataFrame(rows)
    current_pcr = round(temp_df['put_oi'].sum() / temp_df['call_oi'].sum(), 2)
    current_time = datetime.now().strftime("%H:%M:%S")

    pcr_history.append({'time': current_time, 'pcr': current_pcr})
    print(f"{current_time} — PCR: {current_pcr}")

    if i < 4:
        time.sleep(30)

print("Done.")

# %%
pcr_df = pd.DataFrame(pcr_history)

plt.figure(figsize=(10, 4))
plt.plot(pcr_df['time'], pcr_df['pcr'], color='yellow', linewidth=2, marker='o')
plt.axhline(y=1.2, color='green', linestyle='--', alpha=0.5, label='Bullish (1.2)')
plt.axhline(y=0.8, color='red', linestyle='--', alpha=0.5, label='Bearish (0.8)')
plt.axhline(y=1.0, color='white', linestyle='--', alpha=0.3, label='Neutral (1.0)')
plt.title('PCR Trend')
plt.xlabel('Time')
plt.ylabel('PCR')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# ============================================
# NIFTY OI DASHBOARD
# Built by: Aayush Naithanii
# Description: Live Nifty Options OI Analysis
# Data Source: Upstox API
# ============================================

import requests
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime

# ---- CONFIG ----
TOKEN = "YOUR_TOKEN_HERE"
EXPIRY = "2026-06-16"
SYMBOL = "NSE_INDEX|Nifty 50"

# ---- FETCH DATA ----
def fetch_options_chain(token, symbol, expiry):
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/json"
    }
    response = requests.get(
        "https://api.upstox.com/v2/option/chain",
        headers=headers,
        params={"instrument_key": symbol, "expiry_date": expiry}
    )
    return response.json()

# ---- BUILD DATAFRAME ----
def build_dataframe(data):
    rows = []
    for item in data['data']:
        rows.append({
            'strike': item['strike_price'],
            'call_oi': item['call_options']['market_data']['oi'],
            'put_oi': item['put_options']['market_data']['oi'],
            'call_ltp': item['call_options']['market_data']['ltp'],
            'put_ltp': item['put_options']['market_data']['ltp'],
        })
    return pd.DataFrame(rows)

# ---- CALCULATE PCR ----
def calculate_pcr(df):
    return round(df['put_oi'].sum() / df['call_oi'].sum(), 2)

# ---- CALCULATE MAX PAIN ----
def calculate_max_pain(df):
    max_pain_strike = None
    min_pain = float('inf')
    for _, row in df.iterrows():
        strike = row['strike']
        call_pain = ((df[df['strike'] < strike]['strike'] - strike).abs() * df[df['strike'] < strike]['call_oi']).sum()
        put_pain = ((df[df['strike'] > strike]['strike'] - strike).abs() * df[df['strike'] > strike]['put_oi']).sum()
        total_pain = call_pain + put_pain
        if total_pain < min_pain:
            min_pain = total_pain
            max_pain_strike = strike
    return max_pain_strike

# ---- GET SPOT PRICE ----
def get_spot():
    nifty = yf.Ticker("^NSEI")
    return round(nifty.history(period="1d")['Close'].iloc[-1])

# ---- PLOT DASHBOARD ----
def plot_dashboard(df, spot, max_pain, pcr):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

    # Chart 1 - OI by Strike
    ax1.bar(df['strike'], df['call_oi'], color='red', alpha=0.7, label='Call OI')
    ax1.bar(df['strike'], df['put_oi'], color='green', alpha=0.7, label='Put OI')
    ax1.axvline(x=spot, color='yellow', linestyle='--', label=f'Spot: {spot}')
    ax1.axvline(x=max_pain, color='white', linestyle='--', label=f'Max Pain: {max_pain}')
    ax1.set_title(f'Nifty OI by Strike | PCR: {pcr} | Max Pain: {max_pain}')
    ax1.set_xlabel('Strike Price')
    ax1.set_ylabel('Open Interest')
    ax1.legend()
    ax1.tick_params(axis='x', rotation=45)

    # Chart 2 - PCR Signal
    colors = {'BULLISH': 'green', 'BEARISH': 'red', 'NEUTRAL': 'yellow'}
    if pcr > 1.2:
        signal = 'BULLISH'
    elif pcr < 0.8:
        signal = 'BEARISH'
    else:
        signal = 'NEUTRAL'

    ax2.barh(['PCR'], [pcr], color=colors[signal], alpha=0.8)
    ax2.axvline(x=1.2, color='green', linestyle='--', label='Bullish (1.2)')
    ax2.axvline(x=0.8, color='red', linestyle='--', label='Bearish (0.8)')
    ax2.axvline(x=1.0, color='white', linestyle='--', alpha=0.5, label='Neutral (1.0)')
    ax2.set_title(f'PCR Signal: {signal} ({pcr})')
    ax2.set_xlim(0, 2)
    ax2.legend()

    plt.suptitle(f'Nifty Options Dashboard | {datetime.now().strftime("%d %b %Y %H:%M")}',
                 fontsize=14, y=1.02)
    plt.tight_layout()
    plt.show()

# ---- RUN ----
print("Fetching live data...")
raw_data = fetch_options_chain(TOKEN, SYMBOL, EXPIRY)
df = build_dataframe(raw_data)
pcr = calculate_pcr(df)
max_pain = calculate_max_pain(df)
spot = get_spot()

print(f"Spot: {spot} | Max Pain: {max_pain} | PCR: {pcr}")
plot_dashboard(df, spot, max_pain, pcr)
